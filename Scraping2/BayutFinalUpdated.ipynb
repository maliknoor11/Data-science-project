# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re 
import time

# 1. Define the base URL of the website
base_url = "https://www.bayut.om/en/oman/properties-for-sale/"

# List to store all scraped property data
all_properties_data = []

print(f"Starting to scrape from: {base_url}")

# Set up headers to look like a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
}

# Try pages automatically until no more properties found
page_num = 1
while True:
    if page_num == 1:
        page_url = "https://www.bayut.om/en/oman/properties-for-sale/"
    else:
        page_url = f"https://www.bayut.om/en/oman/properties-for-sale/?page={page_num}"
    
    print(f"\nScraping page {page_num}: {page_url}")
    
    try:
        # Add delays between pages to avoid being blocked
        if page_num > 1:
            print("Waiting 5 seconds before next page...")
            time.sleep(5)
            
        response = requests.get(page_url, headers=headers, timeout=30)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching page {page_url}: {e}")
        break  # Stop if we can't access the page

    soup = BeautifulSoup(response.text, 'html.parser')
    
    property_articles = soup.select('article')
    
    if not property_articles:
        print(f"No property articles found on page {page_num}. End of scraping.")
        break  # No more properties, we've reached the end

    print(f"Found {len(property_articles)} properties on page {page_num}")

    # Extract data from each individual property page
    for property_item in property_articles:
        try:
            # Get the link to individual property page
            title_link = property_item.find('a')
            if not title_link or not title_link.get('href'):
                continue
                
            property_url = requests.compat.urljoin(base_url, title_link.get('href'))
            
            print(f"  Visiting property: {property_url}")
            
            # Visit individual property page
            try:
                property_response = requests.get(property_url, headers=headers, timeout=15)
                property_response.raise_for_status()
                property_soup = BeautifulSoup(property_response.text, 'html.parser')
                
                # Add small delay between property visits
                time.sleep(1)
                
            except requests.exceptions.RequestException as e:
                print(f"    Error fetching property {property_url}: {e}")
                continue
            
            # Extract title from property page
            title_elem = property_soup.find('h1')
            title = title_elem.text.strip() if title_elem else 'N/A'
            
            # Extract price from property page
            price = 'N/A'
            price_text = property_soup.get_text()
            price_match = re.search(r'OMR\s*[\d,]+', price_text)
            if price_match:
                price = price_match.group(0)
            
            # Extract bedrooms from property page text
            bedroom_match = re.search(r'(\d+)\s*Bed', price_text, re.I)
            bedrooms = bedroom_match.group(1) if bedroom_match else 'N/A'
            
            # Extract bathrooms from property page text
            bathroom_match = re.search(r'(\d+)\s*Bath', price_text, re.I)
            bathrooms = bathroom_match.group(1) if bathroom_match else 'N/A'
            
            # Extract area from property page text
            area_match = re.search(r'(\d+(?:,\d+)?)\s*Sq\.\s*M\.', price_text, re.I)
            area = area_match.group(1) + ' Sq. M.' if area_match else 'N/A'
            
            # Extract location from property page (targeting the exact highlighted location)
            location = 'N/A'
            
            # Method 1: Look for the location that appears right under the price
            h2_elements = property_soup.find_all('h2')
            for h2 in h2_elements:
                h2_text = h2.get_text(strip=True)
                # Check if it looks like a location (has comma, reasonable length)
                if ',' in h2_text and len(h2_text) < 30 and len(h2_text) > 8:
                    if 'Property' not in h2_text and 'Information' not in h2_text:
                        location = h2_text
                        break
            
            # Method 2: Look for specific location patterns in divs near price
            if location == 'N/A':
                # Look for divs that might contain the highlighted location
                all_divs = property_soup.find_all('div')
                for div in all_divs:
                    div_text = div.get_text(strip=True)
                    # Look for "City, Region" pattern that matches Oman locations
                    if (',' in div_text and len(div_text) < 25 and 
                        ('Muscat' in div_text or 'Al ' in div_text or 'Qantab' in div_text or 
                         'Salalah' in div_text or 'Dhofar' in div_text)):
                        if ('Property' not in div_text and 'Features' not in div_text and 
                            'Information' not in div_text):
                            location = div_text
                            break
            
            if location == 'N/A' and title != 'N/A' and 'in ' in title:
                parts = title.split('in ', 1)
                if len(parts) > 1:
                    location = parts[1].strip()
                    
            print(f"    → Location found: {location}")  # Debug print
            
            # Determine property type from title
            property_type = 'Other'
            if title != 'N/A':
                if 'Villa' in title:
                    property_type = 'Villa'
                elif 'Apartment' in title:
                    property_type = 'Apartment'
                elif 'Townhouse' in title:
                    property_type = 'Townhouse'
            
            property_data = {
                'Title': title,
                'Price': price,
                'Bedrooms': bedrooms,
                'Bathrooms': bathrooms,
                'Area': area,
                'Location': location,
                'Property_Type': property_type,
                'URL': property_url,
                'Page': page_num
            }
            
            all_properties_data.append(property_data)
            
        except Exception as e:
            print(f"Error extracting property data: {e}")
            continue

    print(f"Extracted {len([p for p in all_properties_data if p['Page'] == page_num])} properties from page {page_num}")
    
    # # TESTING: Stop after 10 properties to check quality
    # if len(all_properties_data) >= 10:
    #     print("\n=== STOPPING AFTER 10 PROPERTIES FOR TESTING ===")
    #     break
    
    # Safety limit to prevent infinite loops
    if page_num >= 100:  # Max 100 pages
        print("Reached maximum page limit (100). Stopping.")
        break
    
    page_num += 1

print(f"\nScraping completed! Total properties: {len(all_properties_data)}")

df = pd.DataFrame(all_properties_data)

# Save the data
df.to_csv('bayut_simple_data.csv', index=False)
print("Data saved to 'bayut_simple_data.csv'")

df
# Out:
# Starting to scrape from: https://www.bayut.om/en/oman/properties-for-sale/
#
# Scraping page 1: https://www.bayut.om/en/oman/properties-for-sale/
# Found 24 properties on page 1
#   Visiting property: https://www.bayut.om/en/property/details-500024648.html
#     → Location found: Qantab, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-500024649.html
#     → Location found: Mahut, Al Wusta
#   Visiting property: https://www.bayut.om/en/property/details-500024621.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-500024573.html
#     → Location found: Hamra, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-500024653.html
#     → Location found: Al Sinainah, Al Buraimi
#   Visiting property: https://www.bayut.om/en/property/details-500024652.html
#     → Location found: Al Duqum, Al Wusta
#   Visiting property: https://www.bayut.om/en/property/details-500024624.html
#     → Location found: Al Duqum, Al Wusta
#   Visiting property: https://www.bayut.om/en/property/details-500024627.html
#     → Location found: Muqshin, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130322503.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130329918.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130323776.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130321577.html
#     → Location found: Al Seeb, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130288092.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130288051.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130288045.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130287829.html
#     → Location found: Al Ghubrah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130285481.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130285475.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130303215.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130292630.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130287331.html
#     → Location found: The Wave (Almouj) Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130285087.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130281899.html
#     → Location found: Qantab, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130281883.html
#     → Location found: Qantab, Muscat
# Extracted 24 properties from page 1
#
# Scraping page 2: https://www.bayut.om/en/oman/properties-for-sale/?page=2
# Waiting 5 seconds before next page...
# Found 24 properties on page 2
#   Visiting property: https://www.bayut.om/en/property/details-130325918.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130296535.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130288165.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130282526.html
#     → Location found: Sultan Haitham City, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130282543.html
#     → Location found: Sultan Haitham City, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130282566.html
#     → Location found: Sultan Haitham City, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130273586.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130273305.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130272566.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130282994.html
#     → Location found: Al Seeb, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130266625.html
#     → Location found: Muscat - Other, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130301309.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130295729.html
#     → Location found: Yiti, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130329678.html
#     → Location found: Yiti, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130306966.html
#     → Location found: Ghala, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130300440.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130289813.html
#     → Location found: Qurum, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130279256.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130270497.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130270582.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130270418.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130257296.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130328953.html
#     → Location found: Yiti, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130286222.html
#     → Location found: Al Maabilah, Muscat
# Extracted 24 properties from page 2
#
# Scraping page 3: https://www.bayut.om/en/oman/properties-for-sale/?page=3
# Waiting 5 seconds before next page...
# Found 24 properties on page 3
#   Visiting property: https://www.bayut.om/en/property/details-130258665.html
#     → Location found: Thumrait, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130286239.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130288041.html
#     → Location found: Madinat As Sultan Qaboos, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130279790.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-500024562.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130287384.html
#     → Location found: Qurum, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130294133.html
#     → Location found: The Wave (Almouj) Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130272074.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130304185.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130283306.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130283342.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130260558.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130314419.html
#     → Location found: Al Khoud, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130322635.html
#     → Location found: Mirbat, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130306849.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130300184.html
#     → Location found: Yiti, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130300176.html
#     → Location found: Yiti, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130263239.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-500024574.html
#     → Location found: Oman
#   Visiting property: https://www.bayut.om/en/property/details-130262532.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130303602.html
#     → Location found: Al Khuwair, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130306981.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130303472.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130260258.html
#     → Location found: Al Sifah, Muscat
# Extracted 24 properties from page 3
#
# Scraping page 4: https://www.bayut.om/en/oman/properties-for-sale/?page=4
# Waiting 5 seconds before next page...
# Found 24 properties on page 4
#   Visiting property: https://www.bayut.om/en/property/details-130288064.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130326939.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130291600.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130301210.html
#     → Location found: Misfah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130298050.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130298134.html
#     → Location found: Al Khoud, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130298064.html
#     → Location found: Al Khoud, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130298043.html
#     → Location found: Al Mawaleh, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130304903.html
#     → Location found: Taqah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130273642.html
#     → Location found: Ansab, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130289802.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130283301.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130288072.html
#     → Location found: Al Hail, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130298729.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130282076.html
#     → Location found: Yiti, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130252100.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130251449.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130299827.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130303802.html
#     → Location found: Al Hail, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130255734.html
#     → Location found: Taqah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130283335.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130267674.html
#     → Location found: Ghala, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130275121.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130256591.html
#     → Location found: Al Seeb, Muscat
# Extracted 24 properties from page 4
#
# Scraping page 5: https://www.bayut.om/en/oman/properties-for-sale/?page=5
# Waiting 5 seconds before next page...
# Found 24 properties on page 5
#   Visiting property: https://www.bayut.om/en/property/details-130322807.html
#     → Location found: Nizwa, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-130289629.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130287932.html
#     → Location found: Qurum, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130265096.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130261626.html
#     → Location found: Al Mawaleh, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130278899.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130295744.html
#     → Location found: Al Seeb, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130300903.html
#     → Location found: Ruwi, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130247537.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130285548.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130261539.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130286390.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130267713.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130247082.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130248154.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130303882.html
#     → Location found: Ghala, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130291257.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130258651.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130303568.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130328908.html
#     → Location found: Al Hail, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130306962.html
#     → Location found: Bosher, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130300163.html
#     → Location found: Yiti, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130273198.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130270855.html
#     → Location found: Al Maabilah, Muscat
# Extracted 24 properties from page 5
#
# Scraping page 6: https://www.bayut.om/en/oman/properties-for-sale/?page=6
# Waiting 5 seconds before next page...
# Found 24 properties on page 6
#   Visiting property: https://www.bayut.om/en/property/details-130270861.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130270875.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130261444.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130283755.html
#     → Location found: Azaiba, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130257370.html
#     → Location found: Muscat - Other, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130240523.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130291151.html
#     → Location found: Al Hail, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130298114.html
#     → Location found: Al Hail, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130287249.html
#     → Location found: Al Seeb, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130234981.html
#     → Location found: Al Mawaleh, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130266493.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130299785.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130233566.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130264669.html
#     → Location found: Al Khoud, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130217993.html
#     → Location found: Shinas, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130218065.html
#     → Location found: Shinas, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130218083.html
#     → Location found: Saham, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130225728.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130242325.html
#     → Location found: Bosher, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130215187.html
#     → Location found: Al Khoud, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130280783.html
#     → Location found: Sumail, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-130271009.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130215926.html
#     → Location found: Saham, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130324655.html
#     → Location found: Al Amarat, Muscat
# Extracted 24 properties from page 6
#
# Scraping page 7: https://www.bayut.om/en/oman/properties-for-sale/?page=7
# Waiting 5 seconds before next page...
# Found 24 properties on page 7
#   Visiting property: https://www.bayut.om/en/property/details-130300155.html
#     → Location found: Yiti, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130219535.html
#     → Location found: Sohar, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130269303.html
#     → Location found: Al Rustaq, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130263058.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130258009.html
#     → Location found: Al Masn'a, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130283721.html
#     → Location found: Saham, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130258834.html
#     → Location found: Al Duqum, Al Wusta
#   Visiting property: https://www.bayut.om/en/property/details-130237219.html
#     → Location found: Al Rustaq, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130252768.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130257089.html
#     → Location found: Ansab, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130280465.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130236522.html
#     → Location found: Suwaiq, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130258519.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130248320.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130256806.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130251643.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130252189.html
#     → Location found: Ansab, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130248309.html
#     → Location found: Yiti, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130248269.html
#     → Location found: Ghala, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130248334.html
#     → Location found: Qurum, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130248426.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130248296.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130254904.html
#     → Location found: Nizwa, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-130212745.html
#     → Location found: Salalah, Dhofar
# Extracted 24 properties from page 7
#
# Scraping page 8: https://www.bayut.om/en/oman/properties-for-sale/?page=8
# Waiting 5 seconds before next page...
# Found 24 properties on page 8
#   Visiting property: https://www.bayut.om/en/property/details-130220012.html
#     → Location found: Al Buraimi, Al Buraimi
#   Visiting property: https://www.bayut.om/en/property/details-130261787.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130258598.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130249736.html
#     → Location found: Al Khoud, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130247612.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130291228.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130258541.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130291171.html
#     → Location found: Ibra, Al Sharqiya
#   Visiting property: https://www.bayut.om/en/property/details-130282204.html
#     → Location found: Bosher, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130252214.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130284794.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130328071.html
#     → Location found: Sumail, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-130208994.html
#     → Location found: Azaiba, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130258609.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130257547.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130304342.html
#     → Location found: Bosher, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130300884.html
#     → Location found: Yiti, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130245541.html
#     → Location found: Sultan Haitham City, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130239450.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130258167.html
#     → Location found: Ibra, Al Sharqiya
#   Visiting property: https://www.bayut.om/en/property/details-130269682.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130246705.html
#     → Location found: Sultan Haitham City, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130256709.html
#     → Location found: Al Seeb, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130249697.html
#     → Location found: Al Amarat, Muscat
# Extracted 24 properties from page 8
#
# Scraping page 9: https://www.bayut.om/en/oman/properties-for-sale/?page=9
# Waiting 5 seconds before next page...
# Found 24 properties on page 9
#   Visiting property: https://www.bayut.om/en/property/details-130257245.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130313194.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130258653.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130261710.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130303283.html
#     → Location found: Bosher, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130252763.html
#     → Location found: Sultan Haitham City, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130204798.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130291194.html
#     → Location found: Sultan Haitham City, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130239033.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130232836.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130238200.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130286492.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130283635.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130182057.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130238745.html
#     → Location found: Al Khoud, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130300973.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130270607.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130258325.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130258343.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130263031.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130233562.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130215103.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130212202.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130212687.html
#     → Location found: The Wave (Almouj), Muscat
# Extracted 24 properties from page 9
#
# Scraping page 10: https://www.bayut.om/en/oman/properties-for-sale/?page=10
# Waiting 5 seconds before next page...
# Found 24 properties on page 10
#   Visiting property: https://www.bayut.om/en/property/details-130240676.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130188563.html
#     → Location found: Al Seeb, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130181030.html
#     → Location found: Al Mawaleh, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130213877.html
#     → Location found: Madinat As Sultan Qaboos, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130230197.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130179203.html
#     → Location found: Al Khaboura, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130245097.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130230633.html
#     → Location found: Ghala, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130225332.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130222373.html
#     → Location found: Al Hail, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130293688.html
#     → Location found: Bosher, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130197815.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130197475.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130190097.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130191703.html
#     → Location found: Qurum, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130186495.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130188400.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130184606.html
#     → Location found: Al Mawaleh, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130184299.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130231178.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130239300.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130266933.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130201294.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130190819.html
#     → Location found: Al Maabilah, Muscat
# Extracted 24 properties from page 10
#
# Scraping page 11: https://www.bayut.om/en/oman/properties-for-sale/?page=11
# Waiting 5 seconds before next page...
# Found 24 properties on page 11
#   Visiting property: https://www.bayut.om/en/property/details-130228099.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130228163.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130208352.html
#     → Location found: Qantab, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130191806.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130183526.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130246453.html
#     → Location found: Sultan Haitham City Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130246525.html
#     → Location found: Sultan Haitham City, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130246447.html
#     → Location found: Sultan Haitham City, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130175026.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130175064.html
#     → Location found: Ansab, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130175086.html
#     → Location found: Bosher, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130274895.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130322318.html
#     → Location found: Al Hail, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130208402.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130204744.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130206036.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130206002.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130288485.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130195059.html
#     → Location found: Misfah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130183195.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130191902.html
#     → Location found: Muscat - Other, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130257865.html
#     → Location found: Qantab, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130222828.html
#     → Location found: Suwaiq, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130258255.html
#     → Location found: Salalah, Dhofar
# Extracted 24 properties from page 11
#
# Scraping page 12: https://www.bayut.om/en/oman/properties-for-sale/?page=12
# Waiting 5 seconds before next page...
# Found 24 properties on page 12
#   Visiting property: https://www.bayut.om/en/property/details-130258316.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130239954.html
#     → Location found: Al Seeb, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130308969.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130229651.html
#     → Location found: Al Seeb, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130258418.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130200300.html
#     → Location found: Darsait, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130197862.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130187754.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130266876.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130222717.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130245551.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130197328.html
#     → Location found: Ghala, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130283630.html
#     → Location found: Saham, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130283597.html
#     → Location found: Sohar, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130183348.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130254217.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130245431.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130270218.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130171553.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130183881.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130238084.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130202787.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130280585.html
#     → Location found: Bosher, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130277837.html
#     → Location found: Barka, Al Batinah
# Extracted 24 properties from page 12
#
# Scraping page 13: https://www.bayut.om/en/oman/properties-for-sale/?page=13
# Waiting 5 seconds before next page...
# Found 24 properties on page 13
#   Visiting property: https://www.bayut.om/en/property/details-130184768.html
#     → Location found: Qantab, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130283147.html
#     → Location found: Bosher, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130246211.html
#     → Location found: Al Masn'a, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130212031.html
#     → Location found: Al Ghubrah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130282145.html
#     → Location found: Adam, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-130183132.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130246537.html
#     → Location found: Sultan Haitham City, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130304916.html
#     → Location found: Al Khaboura, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130230323.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130258495.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130258007.html
#     → Location found: Qantab, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130258333.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130257779.html
#     → Location found: Qantab, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130224189.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130322330.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130310941.html
#     → Location found: Al Buraimi, Al Buraimi
#   Visiting property: https://www.bayut.om/en/property/details-130300560.html
#     → Location found: Izki, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-130256615.html
#     → Location found: Al Seeb, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130187444.html
#     → Location found: The Wave (Almouj) Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130164648.html
#     → Location found: Al Khoud, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130202078.html
#     → Location found: The Wave (Almouj) Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130225546.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130250057.html
#     → Location found: Sultan Haitham City, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130312037.html
#     → Location found: Sumail, Al Dakhiliya
# Extracted 24 properties from page 13
#
# Scraping page 14: https://www.bayut.om/en/oman/properties-for-sale/?page=14
# Waiting 5 seconds before next page...
# Found 24 properties on page 14
#   Visiting property: https://www.bayut.om/en/property/details-130269601.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130171011.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130167167.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130167177.html
#     → Location found: Yiti, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130186626.html
#     → Location found: Bosher, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130241195.html
#     → Location found: Al Khoud, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130321672.html
#     → Location found: Nizwa, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-130204988.html
#     → Location found: Al Khoud, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130308504.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130246501.html
#     → Location found: Sultan Haitham City, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130205049.html
#     → Location found: Bosher, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130196297.html
#     → Location found: Ansab, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130249951.html
#     → Location found: Al Khoud, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130269173.html
#     → Location found: Al Seeb, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130319851.html
#     → Location found: Bosher, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130224376.html
#     → Location found: Ibra, Al Sharqiya
#   Visiting property: https://www.bayut.om/en/property/details-130173797.html
#     → Location found: Qurum, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130258354.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130267127.html
#     → Location found: Al Mawaleh, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130267122.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130191585.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130159421.html
#     → Location found: Azaiba, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130277767.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130247963.html
#     → Location found: Barka, Al Batinah
# Extracted 24 properties from page 14
#
# Scraping page 15: https://www.bayut.om/en/oman/properties-for-sale/?page=15
# Waiting 5 seconds before next page...
# Found 24 properties on page 15
#   Visiting property: https://www.bayut.om/en/property/details-130191568.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130189301.html
#     → Location found: Nizwa, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-130314602.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130313392.html
#     → Location found: Bahla, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-130312334.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130303492.html
#     → Location found: Bahla, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-130288162.html
#     → Location found: Al Rustaq, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130199480.html
#     → Location found: Bosher, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130282790.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130278879.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130175145.html
#     → Location found: Al Sifah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130266471.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130136243.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130256545.html
#     → Location found: Al Mudaibi, Al Sharqiya
#   Visiting property: https://www.bayut.om/en/property/details-130298862.html
#     → Location found: Masira, Al Sharqiya
#   Visiting property: https://www.bayut.om/en/property/details-130207089.html
#     → Location found: Al Hail, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130274163.html
#     → Location found: Ibri, Al Dhahirah
#   Visiting property: https://www.bayut.om/en/property/details-130223181.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130257930.html
#     → Location found: Qantab, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130252652.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130314963.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130310015.html
#     → Location found: Al Seeb, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130169325.html
#     → Location found: Al Khoud, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130155597.html
#     → Location found: Bosher, Muscat
# Extracted 24 properties from page 15
#
# Scraping page 16: https://www.bayut.om/en/oman/properties-for-sale/?page=16
# Waiting 5 seconds before next page...
# Found 24 properties on page 16
#   Visiting property: https://www.bayut.om/en/property/details-130135812.html
#     → Location found: Qurum, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130248345.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130313345.html
#     → Location found: Al Buraimi, Al Buraimi
#   Visiting property: https://www.bayut.om/en/property/details-130303563.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130205487.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-130144339.html
#     → Location found: Ansab, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130262835.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130168165.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130237408.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130180242.html
#     → Location found: Sohar, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130162563.html
#     → Location found: Al Qabil, Al Sharqiya
#   Visiting property: https://www.bayut.om/en/property/details-130283015.html
#     → Location found: Al 'Awabi, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-130151507.html
#     → Location found: Sultan Haitham City, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130307374.html
#     → Location found: Muscat Hills, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130222776.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130143196.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-130238861.html
#     → Location found: Al Sharqiya - Ja'alan Bani Bu Ali
#   Visiting property: https://www.bayut.om/en/property/details-130227688.html
#     → Location found: Yiti, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130184443.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130138040.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130174959.html
#     → Location found: Al Mawaleh, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130156486.html
#     → Location found: Bosher, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130156467.html
#     → Location found: Bosher, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-130310369.html
#     → Location found: Barka, Al Batinah
# Extracted 24 properties from page 16
#
# Scraping page 17: https://www.bayut.om/en/oman/properties-for-sale/?page=17
# ...
# Found 24 properties on page 72
#   Visiting property: https://www.bayut.om/en/property/details-127340027.html
#     → Location found: Bahla, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-126693302.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-127712872.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-110607763.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-111783512.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-128140298.html
#     → Location found: Saham, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-127267153.html
#     → Location found: Sumail, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-127201358.html
#     → Location found: Hamra, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-127701522.html
#     → Location found: Al Mawaleh, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-127470202.html
#     → Location found: Al Masn'a, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-120715294.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-127619108.html
#     → Location found: Al Seeb, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-124446777.html
#     → Location found: Al Seeb, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-120355079.html
#     → Location found: Al Buraimi, Al Buraimi
#   Visiting property: https://www.bayut.om/en/property/details-120352331.html
#     → Location found: Al Buraimi, Al Buraimi
#   Visiting property: https://www.bayut.om/en/property/details-120771092.html
#     → Location found: Sohar, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-124934249.html
#     → Location found: Ibra, Al Sharqiya
#   Visiting property: https://www.bayut.om/en/property/details-125893309.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-124905893.html
#     → Location found: Ibri, Al Dhahirah
#   Visiting property: https://www.bayut.om/en/property/details-111079024.html
#     → Location found: Nizwa, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-120210425.html
#     → Location found: Bidbid, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-120006158.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-110789307.html
#     → Location found: N/A
#   Visiting property: https://www.bayut.om/en/property/details-122880084.html
#     → Location found: Sohar, Al Batinah
# Extracted 24 properties from page 72
#
# Scraping page 73: https://www.bayut.om/en/oman/properties-for-sale/?page=73
# Waiting 5 seconds before next page...
# Found 24 properties on page 73
#   Visiting property: https://www.bayut.om/en/property/details-125297504.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-120350507.html
#     → Location found: Ja'alan Bani Bu Ali, Al Sharqiya
#   Visiting property: https://www.bayut.om/en/property/details-121288245.html
#     → Location found: Salalah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-108519899.html
#     → Location found: Al Mawaleh, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-122540577.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-124658231.html
#     → Location found: Bosher, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-124231345.html
#     → Location found: Sur, Al Sharqiya
#   Visiting property: https://www.bayut.om/en/property/details-124603443.html
#     → Location found: Adam, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-121104528.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-110446475.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-122554493.html
#     → Location found: The Wave (Almouj) Muscat
#   Visiting property: https://www.bayut.om/en/property/details-125782588.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-122288368.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-122041323.html
#     → Location found: Al Mudaibi, Al Sharqiya
#   Visiting property: https://www.bayut.om/en/property/details-110607832.html
#     → Location found: Bosher, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-111528277.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-123911652.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-123941474.html
#     → Location found: Bosher, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-124810865.html
#     → Location found: Ruwi, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-123805051.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-120138567.html
#     → Location found: Qurayyat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-110519440.html
#     → Location found: Al Seeb, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-110084330.html
#     → Location found: Al Ghubrah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-124009308.html
#     → Location found: Sumail, Al Dakhiliya
# Extracted 24 properties from page 73
#
# Scraping page 74: https://www.bayut.om/en/oman/properties-for-sale/?page=74
# Waiting 5 seconds before next page...
# Found 24 properties on page 74
#   Visiting property: https://www.bayut.om/en/property/details-111662338.html
#     → Location found: Al Seeb, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-111673155.html
#     → Location found: Qurayyat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-111387704.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-108439857.html
#     → Location found: Ibri, Al Dhahirah
#   Visiting property: https://www.bayut.om/en/property/details-121470072.html
#     → Location found: Al Maabilah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-120713130.html
#     → Location found: Al Mawaleh, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-111214587.html
#     → Location found: Al Khoud, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-108453609.html
#     → Location found: Al Seeb, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-108274652.html
#     → Location found: Al Khoud, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-121017706.html
#     → Location found: Saham, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-120337483.html
#     → Location found: Muscat - Other, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-110649291.html
#     → Location found: Qurayyat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-121213943.html
#     → Location found: Nizwa, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-121763052.html
#     → Location found: Al Khoud, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-111402968.html
#     → Location found: Al Rustaq, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-111705109.html
#     → Location found: Al Jazur, Al Wusta
#   Visiting property: https://www.bayut.om/en/property/details-121205368.html
#     → Location found: Bosher, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-109465239.html
#     → Location found: Madinat As Sultan Qaboos, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-111523559.html
#     → Location found: Qurayyat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-120433464.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-120323322.html
#     → Location found: Al Khaboura, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-107204830.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-107856642.html
#     → Location found: Wadi Al Ma'awal, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-108040472.html
#     → Location found: Barka, Al Batinah
# Extracted 24 properties from page 74
#
# Scraping page 75: https://www.bayut.om/en/oman/properties-for-sale/?page=75
# Waiting 5 seconds before next page...
# Found 24 properties on page 75
#   Visiting property: https://www.bayut.om/en/property/details-120755541.html
#     → Location found: Sumail, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-120070642.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-106875460.html
#     → Location found: Darsait, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-110829970.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-109935424.html
#     → Location found: Saham, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-104546211.html
#     → Location found: Al Khuwair, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-107408638.html
#     → Location found: The Wave (Almouj), Muscat
#   Visiting property: https://www.bayut.om/en/property/details-108672171.html
#     → Location found: Muscat - Other, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-108676920.html
#     → Location found: Al Amarat, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-108380466.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-103883203.html
#     → Location found: Qurum, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-105202973.html
#     → Location found: Al Khoud, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-106303968.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-106438081.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-104647721.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-105135318.html
#     → Location found: Misfah, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-105220765.html
#     → Location found: Suwaiq, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-109092190.html
#     → Location found: Barka, Al Batinah
#   Visiting property: https://www.bayut.om/en/property/details-107314597.html
#     → Location found: Al Mudaibi, Al Sharqiya
#   Visiting property: https://www.bayut.om/en/property/details-104327209.html
#     → Location found: Al Seeb, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-110203575.html
#     → Location found: Hamra, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-102869977.html
#     → Location found: Ibri, Al Dhahirah
#   Visiting property: https://www.bayut.om/en/property/details-100305119.html
#     → Location found: Al Seeb, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-101699361.html
#     → Location found: Nizwa, Al Dakhiliya
# Extracted 24 properties from page 75
#
# Scraping page 76: https://www.bayut.om/en/oman/properties-for-sale/?page=76
# Waiting 5 seconds before next page...
# Found 8 properties on page 76
#   Visiting property: https://www.bayut.om/en/property/details-102869924.html
#     → Location found: Ibri, Al Dhahirah
#   Visiting property: https://www.bayut.om/en/property/details-500024651.html
#     → Location found: Dhank, Al Dhahirah
#   Visiting property: https://www.bayut.om/en/property/details-500024614.html
#     → Location found: Taqah, Dhofar
#   Visiting property: https://www.bayut.om/en/property/details-500014877.html
#     → Location found: Haima, Al Wusta
#   Visiting property: https://www.bayut.om/en/property/details-500014779.html
#     → Location found: Mahut, Al Wusta
#   Visiting property: https://www.bayut.om/en/property/details-130088856.html
#     → Location found: Nizwa, Al Dakhiliya
#   Visiting property: https://www.bayut.om/en/property/details-129913838.html
#     → Location found: Yiti, Muscat
#   Visiting property: https://www.bayut.om/en/property/details-129203645.html
#     → Location found: Al Amarat, Muscat
# Extracted 8 properties from page 76
#
# Scraping page 77: https://www.bayut.om/en/oman/properties-for-sale/?page=77
# Waiting 5 seconds before next page...
# Error fetching page https://www.bayut.om/en/oman/properties-for-sale/?page=77: 404 Client Error: Not Found for url: https://www.bayut.om/en/oman/properties-for-sale/?page=77
#
# Scraping completed! Total properties: 1808
# Data saved to 'bayut_simple_data.csv'
#                                                   Title       Price Bedrooms  \
# 0               5 Bedrooms Villa For Sale in Omani City    OMR1,500        5
# 1         3 Bedrooms Apartment For Sale Mahut, Al Wusta    OMR1,200        3
# 2         5 Bedrooms Villa For Sale in Al Sifah, Muscat    OMR1,500        5
# 3      4 Bedrooms Villa For Sale in Hamra, Al Dakhiliya    OMR1,000        4
# 4                 3 Bedrooms Apartment For Sale in Oman  OMR120,000        3
# ...                                                 ...         ...      ...
# 1803       4 Bedrooms Villa For Sale in Haima, Al Wusta    OMR1,000        4
# 1804    1 Bedroom Apartment For Sale in Mahut, Al Wusta      OMR600        1
# 1805  Land For Sale - Residential Land - Al Dakhiliy...    OMR5,800      N/A
# 1806             4 Bedrooms Villa For Sale Yiti, Muscat  OMR491,410        4
# 1807        Residential Land For Sale Al Amarat, Muscat    OMR7,000      N/A
#
#      Bathrooms          Area                 Location Property_Type  \
# 0            5  1,500 Sq. M.           Qantab, Muscat         Villa
# 1            3  1,000 Sq. M.          Mahut, Al Wusta     Apartment
# 2            5  1,000 Sq. M.         Al Sifah, Muscat         Villa
# 3            4  1,000 Sq. M.      Hamra, Al Dakhiliya         Villa
# 4            3    110 Sq. M.  Al Sinainah, Al Buraimi     Apartment
# ...        ...           ...                      ...           ...
# 1803         4  1,000 Sq. M.          Haima, Al Wusta         Villa
# 1804         2     10 Sq. M.          Mahut, Al Wusta     Apartment
# 1805       N/A    600 Sq. M.      Nizwa, Al Dakhiliya         Other
# 1806         5    384 Sq. M.             Yiti, Muscat         Villa
# 1807       N/A    645 Sq. M.        Al Amarat, Muscat         Other
#
#                                                     URL  Page
# 0     https://www.bayut.om/en/property/details-50002...     1
# 1     https://www.bayut.om/en/property/details-50002...     1
# 2     https://www.bayut.om/en/property/details-50002...     1
# 3     https://www.bayut.om/en/property/details-50002...     1
# 4     https://www.bayut.om/en/property/details-50002...     1
# ...                                                 ...   ...
# 1803  https://www.bayut.om/en/property/details-50001...    76
# 1804  https://www.bayut.om/en/property/details-50001...    76
# 1805  https://www.bayut.om/en/property/details-13008...    76
# 1806  https://www.bayut.om/en/property/details-12991...    76
# 1807  https://www.bayut.om/en/property/details-12920...    76
#
# [1808 rows x 9 columns]

# %%
# Save with explicit UTF-8 encoding and proper delimiter
df.to_csv('bayut_properties_clean.csv', index=False, encoding='utf-8-sig', sep=',')
print("Clean CSV saved!")

# Alternative: Save as Excel file directly
df.to_excel('bayut_properties.xlsx', index=False)
print("Excel file saved!")
# Out:
# Clean CSV saved!
# Excel file saved!

# %%
from IPython.display import FileLink

# Download the clean CSV
display(FileLink('bayut_properties_clean.csv'))

# Download the Excel file  
display(FileLink('bayut_properties.xlsx'))
# Out:
# C:\Users\bbuser\bayut_properties_clean.csv
# C:\Users\bbuser\bayut_properties.xlsx
